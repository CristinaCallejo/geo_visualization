# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Priority-#-1:-Developers-like-to-be-near-successful-tech-startups-that-have-raised-at-least-1-Million-dollars." data-toc-modified-id="Priority-#-1:-Developers-like-to-be-near-successful-tech-startups-that-have-raised-at-least-1-Million-dollars.-1"><strong><em>Priority # 1: Developers like to be near successful tech startups that have raised at least 1 Million dollars.</em></strong></a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Query-1:-Companies-that-have-raised->=-$1.000.000" data-toc-modified-id="Query-1:-Companies-that-have-raised->=-$1.000.000-1.0.0.1">Query 1: Companies that have raised &gt;= $1.000.000</a></span></li></ul></li></ul></li><li><span><a href="#Checking-out-what-kind-of-companies-we-should-focus-on:" data-toc-modified-id="Checking-out-what-kind-of-companies-we-should-focus-on:-1.1">Checking out what kind of companies we should focus on:</a></span></li><li><span><a href="#Dropping-the-ones-that-have-null-value-in-category_code." data-toc-modified-id="Dropping-the-ones-that-have-null-value-in-category_code.-1.2">Dropping the ones that have null value in category_code.</a></span></li></ul></li></ul></div>

# %%
import requests
import json
import os
from dotenv import load_dotenv
import pandas as pd

# %% [markdown]
# qué es esto? from config import my_key

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
client.ironhack
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack')

# %%
dbcomp = client.ironhack.companies

# %%
db= client.ironhack

# %%
dbcomp # client.database.collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'companies')

# %% [markdown]
# ### ***Priority # 1: Developers like to be near successful tech startups that have raised at least 1 Million dollars.***

# %% [markdown]
# ###### Query 1: Companies that have raised >= $1.000.000

# %% [markdown]
# <img src="image_support/total_money_raised.png" />

# %%
Q1 = list(dbcomp.find({"total_money_raised": {"$gte":"$1.0M"}},{"_id":0,"name":1,"total_money_raised":1}))

# %%
len(Q1)
# Out:
# 4810

# %%
type(Q1)
# Out:
# list

# %%
Q1[:10]
# Out:
# [{'name': 'Wetpaint', 'total_money_raised': '$39.8M'},
#  {'name': 'Digg', 'total_money_raised': '$45M'},
#  {'name': 'Facebook', 'total_money_raised': '$2.43B'},
#  {'name': 'Omnidrive', 'total_money_raised': '$800k'},
#  {'name': 'Geni', 'total_money_raised': '$16.5M'},
#  {'name': 'Twitter', 'total_money_raised': '$1.16B'},
#  {'name': 'StumbleUpon', 'total_money_raised': '$18.5M'},
#  {'name': 'Gizmoz', 'total_money_raised': '$18.1M'},
#  {'name': 'Scribd', 'total_money_raised': '$25.8M'},
#  {'name': 'Slacker', 'total_money_raised': '$73.1M'}]

# %% [markdown]
# Created new collection with the resulting companies

# %%
db1M = client.ironhack.gte_1M

# %%
db1M
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'gte_1M')

# %% [markdown]
# #### Checking out what kind of companies we should focus on:

# %%
initialQ2 = db1M.distinct("category_code")
initialQ2[0:5]
# Out:
# [None, 'advertising', 'analytics', 'automotive', 'biotech']

# %% [markdown]
# #### Dropping the ones that have null value in category_code.

# %%
Q2_invalid_catcodes = list(db1M.find(
    {"category_code":{"$type":"null"}
        },
    {"_id":0,"name":1,"category_code":1}))

# %%
len(Q2_invalid_catcodes)
# Out:
# 66

# %%
catcodes = ['advertising','design','enterprise','fashion','games_video','mobile','music','news','photo_video','software','web']

# %%
Q2_cc = list(db1M.find(
    {"category_code": {"$in":catcodes}},
    {"_id":0,"name":1,"category_code":1}))

# %%
len(Q2_cc)
# Out:
# 2937

# %%
q2_music =list(db1M.find(
    {"category_code": "music"},
    {"_id":0,"name":1,"category_code":1,'number_of_employees':1,'founded_year':1,'deadpooled_year':1,'description':1,'overview':1,'total_money_raised':1,'funding_rounds':1,'investments':1,'acquisition'
:1,'acquisitions':1,'offices':1,}))

# %%
len(q2_music)
# Out:
# 24

# %%
print(q2_music[5])
# Out:
# {'name': 'Songkick', 'category_code': 'music', 'number_of_employees': None, 'founded_year': 2007, 'deadpooled_year': None, 'description': 'Concert Listings Site', 'overview': '<p>Launched October 2007 by co-founders Ian Hogarth, Michelle You and Pete Smith, Songkick is an online database of concerts for music enthusiasts. </p>', 'total_money_raised': '$16.6M', 'funding_rounds': [{'id': 848, 'round_code': 'seed', 'source_url': '', 'source_description': '', 'raised_amount': 15000, 'raised_currency_code': 'USD', 'funded_year': 2007, 'funded_month': 6, 'funded_day': 1, 'investments': [{'company': {'name': 'Y Combinator', 'permalink': 'y-combinator'}, 'financial_org': None, 'person': None}]}, {'id': 1843, 'round_code': 'angel', 'source_url': 'http://www.techcrunch.com/2008/03/18/forget-the-movie-go-to-a-concert/', 'source_description': '', 'raised_amount': 1100000, 'raised_currency_code': 'USD', 'funded_year': 2008, 'funded_month': 3, 'funded_day': 1, 'investments': [{'company': None, 'fi
# ...

# %%
type(q2_music)
# Out:
# list

# %%
import json

# %%
q2_music
# Out:
# [{'name': 'Slacker',
#   'category_code': 'music',
#   'number_of_employees': None,
#   'founded_year': 2006,
#   'deadpooled_year': None,
#   'description': 'Music Personalization Suite',
#   'overview': '<p>Slacker is the most complete music service on Earth.  The company delivers free and subscription-based access to millions of songs and hundreds of expert-programmed stations, plus news, sports and talk, on the web, mobile devices, in-car infotainment systems and consumer electronics platforms.  By blending cutting-edge analytics with a team of expert music curators and content programmers, Slacker delivers a seamless music discovery experience and uniquely personalized entertainment.  Slacker was founded in 2006 and is headquartered in San Diego with offices in Palo Alto, CA and New York City.  For more information about Slacker, or to listen for free, visit www.slacker.com</p>',
#   'total_money_raised': '$73.1M',
#   'funding_rounds': [{'id': 12,
#     'round_code': 'b',
# ...

# %%
q2 = json.dumps(q2_music)

# %%
print(type(q2))
# Out:
# <class 'str'>

# %%
db.music.insert_one(q2)#inserrt one y entre paréntesis el json con los datos
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-dc8ad8b894f9> in <module>
# ----> 1 db.music.insert_one(q2)#inserrt one y entre paréntesis el json con los datos
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     690         .. versionadded:: 3.0
#     691         """
# --> 692         common.validate_is_document_type("document", document)
#     693         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     694             document["_id"] = ObjectId()
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymongo/common.py in validate_is_document_type(option, value)
#     500     """Validate the type of method arguments that expect a MongoDB document."""
# ...

# %%
comp_music = ironhack.compmusic

# %%
comp_music.find({},{'offices':1})

# %% [markdown]
# This info will be used to cross-reference the different options, to establish company in a relevant location where other industry key players are involved. [AÑADIR valor de mercado??? api bolsa?]

# %%
len(Q3)
# Out:
# 2

# %%
type(Q3)
# Out:
# list

# %%
Q3[:5]
# Out:
# [{'name': 'GREE',
#   'ipo': {'valuation_amount': 108960000000,
#    'valuation_currency_code': 'JPY',
#    'pub_year': 2008,
#    'pub_month': 12,
#    'pub_day': 17,
#    'stock_symbol': '3632'}},
#  {'name': 'Tudou',
#   'ipo': {'valuation_amount': 174000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': None,
#    'pub_month': None,
#    'pub_day': None,
#    'stock_symbol': 'NASDAQ:TUDO'}}]
